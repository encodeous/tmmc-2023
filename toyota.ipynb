# %%
from ultralytics import YOLO

# Load a model
model = YOLO('yolov8m.pt')  # load a pretrained model (recommended for training)
# Train the model
results = model.train(data='data/data.yaml', epochs=150, dropout=0.01)
# Out:
# Ultralytics YOLOv8.0.202 🚀 Python-3.9.17 torch-2.1.0+cu121 CUDA:0 (NVIDIA GeForce RTX 3080, 10240MiB)
# ...
